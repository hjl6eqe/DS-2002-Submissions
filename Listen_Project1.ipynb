# %%
# https://www.kaggle.com/datasets/heesoo37/120-years-of-olympic-history-athletes-and-results

# The following code enables you to convert a csv file (linked above) to a json or sql file based on your input.
# If you input a file type that is not "csv", "json", or "sql", then you will be asked to reinput
# Regardless of which file type you select, I removed columns that appeared redundant. 
# If you select json, the code writes to a json file locally that is uploaded to git.
# If you select sql, you will get a sql lite file that displays American gold medalists from youngest to oldest (I thought this would be most interesting)
# For all file types, you will see the number of columns and rows (although the sql query I use only displays a narrower selection)

# %%
# Importing the libraries
import json
import requests
import pandas as pd
import csv
import os
import sqlite3

# %%
# Reading in the olympics data set
data_directory = os.path.join(os.getcwd(), '/Users/harrisonlisten/Desktop/UVA/4th-Year/DS2002/Project 1')
data_file = os.path.join(data_directory, 'athlete_events.csv')
olympics = pd.read_csv(data_file, header=0, index_col=0)
olympics.head()
# Out:
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
#
#           Games  Year  Season       City          Sport  \
# ID
# 1   1992 Summer  1992  Summer  Barcelona     Basketball
# 2   2012 Summer  2012  Summer     London           Judo
# 3   1920 Summer  1920  Summer  Antwerpen       Football
# 4   1900 Summer  1900  Summer      Paris     Tug-Of-War
# 5   1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                                Event Medal
# ID
# 1        Basketball Men's Basketball   NaN
# 2       Judo Men's Extra-Lightweight   NaN
# 3            Football Men's Football   NaN
# 4        Tug-Of-War Men's Tug-Of-War  Gold
# 5   Speed Skating Women's 500 metres   NaN

# %%
# Creating the function to convert a csv to json
def csv_json_converter(data_file):
        with open(data_file, encoding = 'utf-8') as csv_converter:
            olympics = pd.read_csv(data_file, header=0, index_col=0)
            olympics.drop(['NOC','Games', 'Sport'], axis = 1,inplace = True)
        with open('olympics.json', 'w', encoding = 'utf-8') as jfile:
            olympics_dict = olympics.to_dict()
            j_string = json.dumps(olympics_dict)
            jfile.write(j_string)

# %%
# Creating the sql connection
con = sqlite3.connect('olympics.db')
cursor = con.cursor()

# %%
# Testing for errors with user input and allowing the user to select their file type.
file_type = input("Do you want a \'csv\', \'json\', or \'sql\' file? " )
while file_type not in ['csv', 'json', 'sql']:
    file_type = input("You did not input one of the file type options. Do you want a \'csv\', \'json\', or \'sql\' file? " )
print("The requested file type is " + file_type)
# Out:
# Do you want a 'csv', 'json', or 'sql' file? sql
# The requested file type is sql

# %%
# Converting the file based on the user's input above
if file_type == "csv":
    olympics = pd.read_csv(data_file, header=0, index_col=0)
    olympics.drop(['NOC','Games', 'Sport'], axis = 1,inplace = True)
    rows = len(olympics.axes[0])
    cols = len(olympics.axes[1])
    print("The number of columns is " +str(cols)+ " and the number of rows is " +str(rows))
    print(olympics.head())
elif file_type == "json":
    olympics = pd.read_csv(data_file, header=0, index_col=0)
    olympics.drop(['NOC','Games', 'Sport'], axis = 1,inplace = True)
    rows = len(olympics.axes[0])
    cols = len(olympics.axes[1])
    print("The number of columns is " +str(cols)+ " and the number of rows is " +str(rows))
    csv_json_converter(data_file)
    print("Your file is now being written to a json format locally.")
elif file_type == "sql":
    olympics = pd.read_csv(data_file, header=0, index_col=0)
    olympics.drop(['NOC','Games', 'Sport'], axis = 1,inplace = True)
    rows = len(olympics.axes[0])
    cols = len(olympics.axes[1])
    print("The number of columns is " +str(cols)+ " and the number of rows is " +str(rows))
    cursor.execute("CREATE TABLE IF NOT EXISTS olympics_sql(name TEXT, age INT, sex TEXT)")
    con.commit()
    olympics.to_sql("olympics_sql", con, if_exists = "replace", index = False)
    cursor.execute('''SELECT name, team, age, event FROM olympics_sql WHERE medal = "Gold" AND team = "United States"
    ORDER BY age''')
    print("Below is a list of all American gold medalists from youngest to oldest:")
    for row in cursor.fetchall():
        print(row)
# Out:
# The number of columns is 11 and the number of rows is 271116
# Below is a list of all American gold medalists from youngest to oldest:
# ('George V. Finnegan', 'United States', None, "Boxing Men's Flyweight")
# ('Charles Mayer', 'United States', None, "Boxing Men's Middleweight")
# ('Donna Elizabeth de Varona (-Pinto)', 'United States', 13.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Marjorie Gestring (-Redlick)', 'United States', 13.0, "Diving Women's Springboard")
# ('Aileen Muriel Riggin (-Soule)', 'United States', 13.0, "Diving Women's Springboard")
# ('Amanda Ray Beard (-Brown)', 'United States', 14.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Barbara Ann Marshall', 'United States', 14.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Dominique Helena Moceanu (-Canales)', 'United States', 14.0, "Gymnastics Women's Team All-Around")
# ('Susan Jane "Sue" Pedersen (-Pankey)', 'United States', 14.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Susan Jane "Sue" Pedersen (-Pankey)', 'United States', 14.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Lillian Debra "Pokey" Watson (-Richardson)', 'United States', 14.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Lillian Debra "Pokey" Watson (-Richardson)', 'United States', 14.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Carolyn Virginia Wood', 'United States', 14.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Carolyn Virginia Wood', 'United States', 14.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Lynne Marie Allsup (-Olson)', 'United States', 15.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Shirley Frances Babashoff', 'United States', 15.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Shirley Frances Babashoff', 'United States', 15.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Melissa Louise Belote (-Hamlin, -Ripley)', 'United States', 15.0, "Swimming Women's 100 metres Backstroke")
# ('Melissa Louise Belote (-Hamlin, -Ripley)', 'United States', 15.0, "Swimming Women's 200 metres Backstroke")
# ('Melissa Louise Belote (-Hamlin, -Ripley)', 'United States', 15.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Elizabeth Anne "Beth" Botsford', 'United States', 15.0, "Swimming Women's 100 metres Backstroke")
# ('Elizabeth Anne "Beth" Botsford', 'United States', 15.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Erika Eloise Bricker (-Holderith)', 'United States', 15.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Deena Diane Deardurff (-Schmidt)', 'United States', 15.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Susan Elizabeth Doerr', 'United States', 15.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Jennifer Leigh Hooker (-Brinegar)', 'United States', 15.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Barbara Pearl Jones (-Slater)', 'United States', 15.0, "Athletics Women's 4 x 100 metres Relay")
# ('Kathleen Genevieve "Katie" Ledecky', 'United States', 15.0, "Swimming Women's 800 metres Freestyle")
# ('Tara Kristen Lipinski (-Kapostasy)', 'United States', 15.0, "Figure Skating Women's Singles")
# ('Martha (Mrta) Maria Norelius (-McAllister, -Wright, -Brown)', 'United States', 15.0, "Swimming Women's 400 metres Freestyle")
# ('Kimberley Marie "Kim" Peyton (-McDonald)', 'United States', 15.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Kyla Briana Ross', 'United States', 15.0, "Gymnastics Women's Team All-Around")
# ('Keena Ruth Rothhammer (-Weisbly, -Zorovich)', 'United States', 15.0, "Swimming Women's 800 metres Freestyle")
# ('Gillian "Jill" Sterkel', 'United States', 15.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Sharon Marie Stouder (-Clark)', 'United States', 15.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Sharon Marie Stouder (-Clark)', 'United States', 15.0, "Swimming Women's 100 metres Butterfly")
# ('Sharon Marie Stouder (-Clark)', 'United States', 15.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Anne Kindel Warner (-Cribbs)', 'United States', 15.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Brooke Marie Bennett (-Frioud)', 'United States', 16.0, "Swimming Women's 800 metres Freestyle")
# ('Molly Ray Botkin (-Rossiter, -Trees)', 'United States', 16.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Jennifer Marie Capriati', 'United States', 16.0, "Tennis Women's Singles")
# ('Gabrielle Christina Victoria "Gabby" Douglas', 'United States', 16.0, "Gymnastics Women's Individual All-Around")
# ('Gabrielle Christina Victoria "Gabby" Douglas', 'United States', 16.0, "Gymnastics Women's Team All-Around")
# ('Cathy Jane Ferguson (-Brennan)', 'United States', 16.0, "Swimming Women's 100 metres Backstroke")
# ('Cathy Jane Ferguson (-Brennan)', 'United States', 16.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('John (Jacob) "Jackie" Fields (Finkelstein-)', 'United States', 16.0, "Boxing Men's Featherweight")
# ('Anne Elizabeth Henning (-Walker)', 'United States', 16.0, "Speed Skating Women's 500 metres")
# ('Lauren Zoe "Laurie" Hernandez', 'United States', 16.0, "Gymnastics Women's Team All-Around")
# ('Sarah Elizabeth Hughes', 'United States', 16.0, "Figure Skating Women's Singles")
# ('Jenna Leigh Johnson', 'United States', 16.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Jenna Leigh Johnson', 'United States', 16.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Shawn Machel Johnson (-East)', 'United States', 16.0, "Gymnastics Women's Balance Beam")
# ('McKayla Rose Maroney', 'United States', 16.0, "Gymnastics Women's Team All-Around")
# ('Deborah Elizabeth "Debbie" Meyer (-Weber)', 'United States', 16.0, "Swimming Women's 200 metres Freestyle")
# ('Deborah Elizabeth "Debbie" Meyer (-Weber)', 'United States', 16.0, "Swimming Women's 400 metres Freestyle")
# ('Deborah Elizabeth "Debbie" Meyer (-Weber)', 'United States', 16.0, "Swimming Women's 800 metres Freestyle")
# ('Nadia Anita Louise Nall (-Richesson)', 'United States', 16.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Sandra Lynn "Sandy" Neilson (-Bell)', 'United States', 16.0, "Swimming Women's 100 metres Freestyle")
# ('Sandra Lynn "Sandy" Neilson (-Bell)', 'United States', 16.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Sandra Lynn "Sandy" Neilson (-Bell)', 'United States', 16.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Carly Rae Patterson (-Caldwell)', 'United States', 16.0, "Gymnastics Women's Individual All-Around")
# ('Jaycie Lynn Phelps (-McClure, -Marus)', 'United States', 16.0, "Gymnastics Women's Team All-Around")
# ('Susan Kay "Sue" Pitt (-Anderson)', 'United States', 16.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Megan M. Quann-Jendrick', 'United States', 16.0, "Swimming Women's 100 metres Breaststroke")
# ('Megan M. Quann-Jendrick', 'United States', 16.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Judith Anne "Judy" Reeder', 'United States', 16.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Mary Lou Retton (-Kelley)', 'United States', 16.0, "Gymnastics Women's Individual All-Around")
# ('Elizabeth M. "Betty" Robinson (-Schwartz)', 'United States', 16.0, "Athletics Women's 100 metres")
# ('Susanne Marie "Susan" Shields (-White)', 'United States', 16.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Dana Jayne Shrader (-Butler)', 'United States', 16.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Carolyn Lynne "Carrie" Steinseifer (-Bates)', 'United States', 16.0, "Swimming Women's 100 metres Freestyle")
# ('Carolyn Lynne "Carrie" Steinseifer (-Bates)', 'United States', 16.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Carolyn Lynne "Carrie" Steinseifer (-Bates)', 'United States', 16.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Dana Whitney Vollmer (-Grant)', 'United States', 16.0, "Swimming Women's 4 x 200 metres Freestyle Relay")
# ('Susan Christina "Chris" von Saltza (-Olmstead)', 'United States', 16.0, "Swimming Women's 400 metres Freestyle")
# ('Susan Christina "Chris" von Saltza (-Olmstead)', 'United States', 16.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Susan Christina "Chris" von Saltza (-Olmstead)', 'United States', 16.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Ashley Ann Whitney', 'United States', 16.0, "Swimming Women's 4 x 200 metres Freestyle Relay")
# ('Sharon Lynn Wichman (-Jones)', 'United States', 16.0, "Swimming Women's 200 metres Breaststroke")
# ('Margaret Ann Bailes (Johnson-)', 'United States', 17.0, "Athletics Women's 4 x 100 metres Relay")
# ('Catherine Northcutt "Catie" Ball (-Condon)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Jane Louise Barkman (-Brown)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Lee Stratford Barnes, Jr.', 'United States', 17.0, "Athletics Men's Pole Vault")
# ('Robert Earl "Bob" Bennett', 'United States', 17.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Lynn Edythe Burke (-McConville)', 'United States', 17.0, "Swimming Women's 100 metres Backstroke")
# ('Lynn Edythe Burke (-McConville)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Lesley Leigh Bush (-Hickcox, -Makepeace)', 'United States', 17.0, "Diving Women's Platform")
# ('Jennifer Kay Bellamy Chandler', 'United States', 17.0, "Diving Women's Springboard")
# ('Austin Rhone Clapp', 'United States', 17.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Stephen Edward "Steve" Clark', 'United States', 17.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Stephen Edward "Steve" Clark', 'United States', 17.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Donna Elizabeth de Varona (-Pinto)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Donna Elizabeth de Varona (-Pinto)', 'United States', 17.0, "Swimming Women's 400 metres Individual Medley")
# ('William Henry Dudley, III', 'United States', 17.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Virginia Ruth "Ginny" Duenkel', 'United States', 17.0, "Swimming Women's 400 metres Freestyle")
# ('Kathleen "Kathy" Ellis (-Landgraf, -Greer)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Kathleen "Kathy" Ellis (-Landgraf, -Greer)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Janet Beth Evans', 'United States', 17.0, "Swimming Women's 400 metres Freestyle")
# ('Janet Beth Evans', 'United States', 17.0, "Swimming Women's 800 metres Freestyle")
# ('Janet Beth Evans', 'United States', 17.0, "Swimming Women's 400 metres Individual Medley")
# ('David William Fairbank', 'United States', 17.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('David William Fairbank', 'United States', 17.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Aria Fischer', 'United States', 17.0, "Water Polo Women's Water Polo")
# ('Melissa Jeanette "Missy" Franklin', 'United States', 17.0, "Swimming Women's 4 x 200 metres Freestyle Relay")
# ('Melissa Jeanette "Missy" Franklin', 'United States', 17.0, "Swimming Women's 100 metres Backstroke")
# ('Melissa Jeanette "Missy" Franklin', 'United States', 17.0, "Swimming Women's 200 metres Backstroke")
# ('Melissa Jeanette "Missy" Franklin', 'United States', 17.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Brian Stuart Goodell', 'United States', 17.0, "Swimming Men's 400 metres Freestyle")
# ('Brian Stuart Goodell', 'United States', 17.0, "Swimming Men's 1,500 metres Freestyle")
# ('Kaye Marie Hall (-Greff)', 'United States', 17.0, "Swimming Women's 100 metres Backstroke")
# ('Kaye Marie Hall (-Greff)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Jeanne Courtney Hallock (-Craig)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Rhiannon "Rhi" Jeffrey', 'United States', 17.0, "Swimming Women's 4 x 200 metres Freestyle Relay")
# ('Helen Eileen Johns (-Carroll)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Thelma H. Kalama (-Aiu)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Pua Kele Kealoha', 'United States', 17.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Warren Daniels Kealoha', 'United States', 17.0, "Swimming Men's 100 metres Backstroke")
# ('Jennifer Jo "Jenny" Kempf', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Megan Adelle Kleine (-Morris)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Ethel Minnie Lackie (-Watkins)', 'United States', 17.0, "Swimming Women's 100 metres Freestyle")
# ('Ethel Minnie Lackie (-Watkins)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Robert Bruce "Bob" Mathias', 'United States', 17.0, "Athletics Men's Decathlon")
# ('James Price "Jimmy" McLane, Jr.', 'United States', 17.0, "Swimming Men's 1,500 metres Freestyle")
# ('James Price "Jimmy" McLane, Jr.', 'United States', 17.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('William Roy "Bill" Mettler, Jr.', 'United States', 17.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Ronald Parker "Ronnie" Mills', 'United States', 17.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Albina Lucy Charlotte Osipowich (-Van Aken)', 'United States', 17.0, "Swimming Women's 100 metres Freestyle")
# ('Albina Lucy Charlotte Osipowich (-Van Aken)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Floyd Patterson', 'United States', 17.0, "Boxing Men's Middleweight")
# ('Dorothy Poynton-Hill (-Teuber)', 'United States', 17.0, "Diving Women's Platform")
# ('Kimberly Susan "Kim" Rhode (-Harryman)', 'United States', 17.0, "Shooting Women's Double Trap")
# ('Richard William "Dick" Roth', 'United States', 17.0, "Swimming Men's 400 metres Individual Medley")
# ('Carolyn Jane Schuler', 'United States', 17.0, "Swimming Women's 100 metres Butterfly")
# ('Carolyn Jane Schuler', 'United States', 17.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Claressa Maria Shields', 'United States', 17.0, "Boxing Women's Middleweight")
# ('Caroline "Carol" Smith (-Macias)', 'United States', 17.0, "Diving Women's Plain High")
# ('Joan Arlene Spillane', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Joan Arlene Spillane', 'United States', 17.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Jane Ellen Swagerty (-Hill)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Ashley Tara Tappin (-Doussan)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Meldrick Taylor', 'United States', 17.0, "Boxing Men's Featherweight")
# ('Dara Grace Torres (-Hoffman, -Minas)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Mariechen M. Wehselau (-Jackson)', 'United States', 17.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Jordyn Marie Wieber', 'United States', 17.0, "Gymnastics Women's Team All-Around")
# ('Wallace Perry "Wally" Wolf, Jr.', 'United States', 17.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Merrill Rowland Wolfe', 'United States', 17.0, "Gymnastics Men's Tumbling")
# ('William Tripp "Bill" Woolsey', 'United States', 17.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Samantha "Sam" Arsenault (-Livingstone)', 'United States', 18.0, "Swimming Women's 4 x 200 metres Freestyle Relay")
# ('Matthew Nicholas "Matt" Biondi', 'United States', 18.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('Ethelda Marguerite Bleibtrey (-Schlatke)', 'United States', 18.0, "Swimming Women's 100 metres Freestyle")
# ('Ethelda Marguerite Bleibtrey (-Schlatke)', 'United States', 18.0, "Swimming Women's 300 metres Freestyle")
# ('Ethelda Marguerite Bleibtrey (-Schlatke)', 'United States', 18.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Rachel Kristine Bootsma', 'United States', 18.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Nathan Eugene "Nate" Brooks', 'United States', 18.0, "Boxing Men's Flyweight")
# ('Richard Totten "Dick" Button', 'United States', 18.0, "Figure Skating Men's Singles")
# ('Mary Louise Carew (-Armstrong)', 'United States', 18.0, "Athletics Women's 4 x 100 metres Relay")
# ('Catherine L. "Cathy" Carr (-West)', 'United States', 18.0, "Swimming Women's 100 metres Breaststroke")
# ('Catherine L. "Cathy" Carr (-West)', 'United States', 18.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Amy Yuen-Yee Chow (-Ho)', 'United States', 18.0, "Gymnastics Women's Team All-Around")
# ('Kelly Clark', 'United States', 18.0, "Snowboarding Women's Halfpipe")
# ('Cassius Marcellus Clay, Jr.', 'United States', 18.0, "Boxing Men's Light-Heavyweight")
# ('Tiffany Lisa Cohen (-Adams, -Lalonde)', 'United States', 18.0, "Swimming Women's 400 metres Freestyle")
# ('Tiffany Lisa Cohen (-Adams, -Lalonde)', 'United States', 18.0, "Swimming Women's 800 metres Freestyle")
# ('Marie Louise Corridon (-Mortell)', 'United States', 18.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Ian Lowell Crocker', 'United States', 18.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Eleanor Suzanne "Ellie" Daniel (-Drye)', 'United States', 18.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Euphrasia Louise "Fraze" Donnelly (-Bungard, -Berlin)', 'United States', 18.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Gertrude Caroline "Trudy" Ederle', 'United States', 18.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Catherine Mai-Lan Fox', 'United States', 18.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Catherine Mai-Lan Fox', 'United States', 18.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Evelyn Pearl Furtsch (-Ojeda)', 'United States', 18.0, "Athletics Women's 4 x 100 metres Relay")
# ('Eleanor Agnes Garatti-Saville', 'United States', 18.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Frank "Frankie" Genaro (DiGennara-)', 'United States', 18.0, "Boxing Men's Flyweight")
# ('Cynthia Lee Goyette (-Shroeder)', 'United States', 18.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Linda Lee Gustavson (-McGuire)', 'United States', 18.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Nina Adams Harmer (-Thompson)', 'United States', 18.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('John Frederick Hencken', 'United States', 18.0, "Swimming Men's 200 metres Breaststroke")
# ('John Frederick Hencken', 'United States', 18.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Eleanor G. Holm (-Jarret, -Rose, -Walker, -Whalen)', 'United States', 18.0, "Swimming Women's 100 metres Backstroke")
# ('Joseph Bernard "Joe" Hudepohl', 'United States', 18.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('John Wesley "Johnny" Jones', 'United States', 18.0, "Athletics Men's 4 x 100 metres Relay")
# ('Patricia "Patty" Kempner', 'United States', 18.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Adolph Gustav Kiefer', 'United States', 18.0, "Swimming Men's 100 metres Backstroke")
# ('George Harold Kojac', 'United States', 18.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('George Harold Kojac', 'United States', 18.0, "Swimming Men's 100 metres Backstroke")
# ('Claudia Anne Kolb', 'United States', 18.0, "Swimming Women's 200 metres Individual Medley")
# ('Claudia Anne Kolb', 'United States', 18.0, "Swimming Women's 400 metres Individual Medley")
# ('Fidel LaBarba', 'United States', 18.0, "Boxing Men's Flyweight")
# ('Anastasiya Valeryevna "Nastia" Liukin', 'United States', 18.0, "Gymnastics Women's Individual All-Around")
# ('Josephine Eveline McKim (-Chalmers)', 'United States', 18.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Julianne Lyn McNamara (-Zeile)', 'United States', 18.0, "Gymnastics Women's Uneven Bars")
# ('Judith Ellen "Judy" Melick', 'United States', 18.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Elizabeth "Betsy" Mitchell', 'United States', 18.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Diana Marie Munz (-DePetro)', 'United States', 18.0, "Swimming Women's 4 x 200 metres Freestyle Relay")
# ('Madeline "Maddie" Musselman', 'United States', 18.0, "Water Polo Women's Water Polo")
# ('Michael Jon "Mike" O\'Brien', 'United States', 18.0, "Swimming Men's 1,500 metres Freestyle")
# ('Yoshinobu "Yoshi" Oyakawa', 'United States', 18.0, "Swimming Men's 100 metres Backstroke")
# ('Cynthia Marie "Cindy" Parlow', 'United States', 18.0, "Football Women's Football")
# ('Alexandra Rose "Aly" Raisman', 'United States', 18.0, "Gymnastics Women's Team All-Around")
# ('Alexandra Rose "Aly" Raisman', 'United States', 18.0, "Gymnastics Women's Floor Exercise")
# ('Leonard "Leo" Randolph', 'United States', 18.0, "Boxing Men's Flyweight")
# ('Peter Drake Rocca', 'United States', 18.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Annette Joan Rogers (-Kelly)', 'United States', 18.0, "Athletics Women's 4 x 100 metres Relay")
# ('Angela Marie Ruggiero', 'United States', 18.0, "Ice Hockey Women's Ice Hockey")
# ('Sylvia Eliina Ruuska', 'United States', 18.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Donald Arthur "Don" Schollander', 'United States', 18.0, "Swimming Men's 100 metres Freestyle")
# ('Donald Arthur "Don" Schollander', 'United States', 18.0, "Swimming Men's 400 metres Freestyle")
# ('Donald Arthur "Don" Schollander', 'United States', 18.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('Donald Arthur "Don" Schollander', 'United States', 18.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Timothy Andrew "Tim" Shaw', 'United States', 18.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Patience Halsey Sherman', 'United States', 18.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Mikaela Pauline Shiffrin', 'United States', 18.0, "Alpine Skiing Women's Slalom")
# ('Mark Andrew Spitz', 'United States', 18.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('Mark Andrew Spitz', 'United States', 18.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Karen Patricia "Pat" Spurgin (-Pitney)', 'United States', 18.0, "Shooting Women's Air Rifle, 10 metres")
# ('Helen Herring Stephens', 'United States', 18.0, "Athletics Women's 100 metres")
# ('Helen Herring Stephens', 'United States', 18.0, "Athletics Women's 4 x 100 metres Relay")
# ('Shirley Anne Stobs', 'United States', 18.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Julia Gray Stowers', 'United States', 18.0, "Swimming Women's 4 x 200 metres Freestyle Relay")
# ('Kerri Allyson Strug (-Fischer)', 'United States', 18.0, "Gymnastics Women's Team All-Around")
# ('Cristina Teuscher', 'United States', 18.0, "Swimming Women's 4 x 200 metres Freestyle Relay")
# ('Frederick Daniel "Fred" Tyler', 'United States', 18.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Elizabeth Jane "Janie" Wagstaff', 'United States', 18.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Michael Allen "Mike" Wall', 'United States', 18.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Lillian Debra "Pokey" Watson (-Richardson)', 'United States', 18.0, "Swimming Women's 200 metres Backstroke")
# ('Christa Lee Williams', 'United States', 18.0, "Softball Women's Softball")
# ('John Chester Williams', 'United States', 18.0, "Archery Men's Individual")
# ('Serena Jamika Williams', 'United States', 18.0, "Tennis Women's Doubles")
# ('Helen Newington Wills (-Moody, -Roark)', 'United States', 18.0, "Tennis Women's Singles")
# ('Christopher W. T. "Chris" Woo', 'United States', 18.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Margaret Darling Woodbridge (-Presley)', 'United States', 18.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Frank Clifford Wykoff', 'United States', 18.0, "Athletics Men's 4 x 100 metres Relay")
# ('Edgar Allen "Ed" Ablowich', 'United States', 19.0, "Athletics Men's 4 x 400 metres Relay")
# ('Nathan Ghar-Jun Adrian', 'United States', 19.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('George Lewis Ahlgren', 'United States', 19.0, "Rowing Men's Coxed Eights")
# ('Stephen Todd "Steve" Alford', 'United States', 19.0, "Basketball Men's Basketball")
# ('Susanne Jean "Susie" Atwood', 'United States', 19.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Shirley Frances Babashoff', 'United States', 19.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Kathleen Baker', 'United States', 19.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Carmine R. "Carmen" Barth (DiBartolomeo-)', 'United States', 19.0, "Boxing Men's Middleweight")
# ('Samuel "Sam" Berger', 'United States', 19.0, "Boxing Men's Heavyweight")
# ('Simone Arianne Biles', 'United States', 19.0, "Gymnastics Women's Individual All-Around")
# ('Simone Arianne Biles', 'United States', 19.0, "Gymnastics Women's Team All-Around")
# ('Simone Arianne Biles', 'United States', 19.0, "Gymnastics Women's Floor Exercise")
# ('Simone Arianne Biles', 'United States', 19.0, "Gymnastics Women's Horse Vault")
# ('Amanda Kathleen Borden (-Cochran)', 'United States', 19.0, "Gymnastics Women's Team All-Around")
# ('John Manning "Jack" Brinck', 'United States', 19.0, "Rowing Men's Coxed Eights")
# ('Michael Lee "Mike" Bruner', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Michael Lee "Mike" Bruner', 'United States', 19.0, "Swimming Men's 200 metres Butterfly")
# ('Gary Robert Conelly', 'United States', 19.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('Gary Robert Conelly', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Edward Tiffin "Ed" Cook, Jr.', 'United States', 19.0, "Athletics Men's Pole Vault")
# ('John Patrick Cooke', 'United States', 19.0, "Rowing Men's Coxed Eights")
# ('William Norval "Bill" Craig', 'United States', 19.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Joseph William "Joe" Crockett', 'United States', 19.0, "Shooting Men's Free Rifle, 400, 600 and 800 metres, Team")
# ('Troy Lane Dalbey', 'United States', 19.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('Troy Lane Dalbey', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Charles Meldrum "Charlie" Daniels', 'United States', 19.0, "Swimming Men's 220 yard Freestyle")
# ('Charles Meldrum "Charlie" Daniels', 'United States', 19.0, "Swimming Men's 440 yard Freestyle")
# ('Anthony Marshon Davis, Jr.', 'United States', 19.0, "Basketball Men's Basketball")
# ('Dominique Margaux Dawes (-Thompson)', 'United States', 19.0, "Gymnastics Women's Team All-Around")
# ('Oscar De La Hoya', 'United States', 19.0, "Boxing Men's Lightweight")
# ('Terence Gilbert "Terry" Dischinger', 'United States', 19.0, "Basketball Men's Basketball")
# ('Diane Lynn Dixon (-Trouse)', 'United States', 19.0, "Athletics Women's 4 x 400 metres Relay")
# ('Burton Cecil Downing', 'United States', 19.0, "Cycling Men's 2 mile")
# ('Burton Cecil Downing', 'United States', 19.0, "Cycling Men's 25 mile")
# ('Caeleb Remel Dressel', 'United States', 19.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('Caeleb Remel Dressel', 'United States', 19.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Charles Everett "Charlie" Dumas', 'United States', 19.0, "Athletics Men's High Jump")
# ('Anthony Lee Ervin', 'United States', 19.0, "Swimming Men's 50 metres Freestyle")
# ('Makenzie Fischer', 'United States', 19.0, "Water Polo Women's Water Polo")
# ('Peggy Gale Fleming (-Jenkins)', 'United States', 19.0, "Figure Skating Women's Singles")
# ('George Edward Foreman', 'United States', 19.0, "Boxing Men's Heavyweight")
# ('Bruce MacFarlane Furniss', 'United States', 19.0, "Swimming Men's 200 metres Freestyle")
# ('Bruce MacFarlane Furniss', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Robert Jerome "Bob" Gibe', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Edwin Fisher Eddie Gilbert', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Harvey Edward Glance', 'United States', 19.0, "Athletics Men's 4 x 100 metres Relay")
# ('Harrison Smith "Harry" Glancy', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Jay Gould, II', 'United States', 19.0, "Jeu De Paume Men's Singles")
# ('Irene May Guest (-Loog)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Francis Townley Haas', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Nicole Lee Haislett (-Bacher)', 'United States', 19.0, "Swimming Women's 200 metres Freestyle")
# ('Nicole Lee Haislett (-Bacher)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Nicole Lee Haislett (-Bacher)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Dorothy Stuart Hamill (-Martin, -Forsythe)', 'United States', 19.0, "Figure Skating Women's Singles")
# ('Vincent Hancock', 'United States', 19.0, "Shooting Men's Skeet")
# ('Spencer Haywood', 'United States', 19.0, "Basketball Men's Basketball")
# ('Denean Elizabeth Howard-Hill', 'United States', 19.0, "Athletics Women's 4 x 400 metres Relay")
# ('Phillip Gregory "Phil" Hubbard', 'United States', 19.0, "Basketball Men's Basketball")
# ('Francis Valentine Joseph "Frank" Hussey', 'United States', 19.0, "Athletics Men's 4 x 100 metres Relay")
# ('Trina Marie Jackson (-Falca)', 'United States', 19.0, "Swimming Women's 4 x 200 metres Freestyle Relay")
# ('Thomas Michael "Tom" Jager', 'United States', 19.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('Thomas Michael "Tom" Jager', 'United States', 19.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Burwell Otis "Bumpy" Jones', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Lilly King', 'United States', 19.0, "Swimming Women's 100 metres Breaststroke")
# ('Lilly King', 'United States', 19.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Howard Thayer Kingsbury, Jr.', 'United States', 19.0, "Rowing Men's Coxed Eights")
# ('Abel Richard Kiviat', 'United States', 19.0, "Athletics Men's 3,000 metres, Team")
# ('Madison Taylor Kocian', 'United States', 19.0, "Gymnastics Women's Team All-Around")
# ('Ford Hiroshi Konno', 'United States', 19.0, "Swimming Men's 1,500 metres Freestyle")
# ('Ford Hiroshi Konno', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Louis Edward "Lou" Kuehn', 'United States', 19.0, "Diving Men's Springboard")
# ('Susanne E. "Susan" Laird (-Scavey)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Kathleen Genevieve "Katie" Ledecky', 'United States', 19.0, "Swimming Women's 200 metres Freestyle")
# ('Kathleen Genevieve "Katie" Ledecky', 'United States', 19.0, "Swimming Women's 400 metres Freestyle")
# ('Kathleen Genevieve "Katie" Ledecky', 'United States', 19.0, "Swimming Women's 800 metres Freestyle")
# ('Kathleen Genevieve "Katie" Ledecky', 'United States', 19.0, "Swimming Women's 4 x 200 metres Freestyle Relay")
# ('Steven Earl "Steve" Lewis', 'United States', 19.0, "Athletics Men's 400 metres")
# ('Steven Earl "Steve" Lewis', 'United States', 19.0, "Athletics Men's 4 x 400 metres Relay")
# ('Helene Emma Madison', 'United States', 19.0, "Swimming Women's 100 metres Freestyle")
# ('Helene Emma Madison', 'United States', 19.0, "Swimming Women's 400 metres Freestyle")
# ('Helene Emma Madison', 'United States', 19.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Shelley Isabel Mann', 'United States', 19.0, "Swimming Women's 100 metres Butterfly")
# ('Thomas Sean "Tom" McBreen', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Andrea Bario Mead-Lawrence', 'United States', 19.0, "Alpine Skiing Women's Giant Slalom")
# ('Andrea Bario Mead-Lawrence', 'United States', 19.0, "Alpine Skiing Women's Slalom")
# ('Mary Terstegge Meagher (-Plant)', 'United States', 19.0, "Swimming Women's 100 metres Butterfly")
# ('Mary Terstegge Meagher (-Plant)', 'United States', 19.0, "Swimming Women's 200 metres Butterfly")
# ('Mary Terstegge Meagher (-Plant)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('William Waring "Bill" Miller', 'United States', 19.0, "Athletics Men's Pole Vault")
# ('Shannon Lee Miller (-Phillips, -Falconetti)', 'United States', 19.0, "Gymnastics Women's Team All-Around")
# ('Shannon Lee Miller (-Phillips, -Falconetti)', 'United States', 19.0, "Gymnastics Women's Balance Beam")
# ('Karen Patricia Moe-Thornton (-Humphreys)', 'United States', 19.0, "Swimming Women's 200 metres Butterfly")
# ('Pedro Pablo Morales, Jr.', 'United States', 19.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Tara Mounsey', 'United States', 19.0, "Ice Hockey Women's Ice Hockey")
# ('John Joseph Murphy', 'United States', 19.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('Martha (Mrta) Maria Norelius (-McAllister, -Wright, -Brown)', 'United States', 19.0, "Swimming Women's 400 metres Freestyle")
# ('Martha (Mrta) Maria Norelius (-McAllister, -Wright, -Brown)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Apolo Anton Ohno', 'United States', 19.0, "Short Track Speed Skating Men's 1,500 metres")
# ('Heather Ann OReilly (-Werry)', 'United States', 19.0, "Football Women's Football")
# ('Darrell Owen Pace', 'United States', 19.0, "Archery Men's Individual")
# ('Charles William "Charley" Paddock', 'United States', 19.0, "Athletics Men's 100 metres")
# ('Charles William "Charley" Paddock', 'United States', 19.0, "Athletics Men's 4 x 100 metres Relay")
# ('Kimberley Marie "Kim" Peyton (-McDonald)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Michael Fred Phelps, II', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Michael Fred Phelps, II', 'United States', 19.0, "Swimming Men's 100 metres Butterfly")
# ('Michael Fred Phelps, II', 'United States', 19.0, "Swimming Men's 200 metres Butterfly")
# ('Michael Fred Phelps, II', 'United States', 19.0, "Swimming Men's 200 metres Individual Medley")
# ('Michael Fred Phelps, II', 'United States', 19.0, "Swimming Men's 400 metres Individual Medley")
# ('Michael Fred Phelps, II', 'United States', 19.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Erin Ashley Phenix', 'United States', 19.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Thomas Steele "Tom" Price', 'United States', 19.0, "Rowing Men's Coxless Pairs")
# ('Michael Allen "Mike" Ramsey', 'United States', 19.0, "Ice Hockey Men's Ice Hockey")
# ('Susan Gerard Rapp (-von der Lippe)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Sanya Richards-Ross', 'United States', 19.0, "Athletics Women's 4 x 400 metres Relay")
# ('Tiffany Marie Roberts (-Sahaydak)', 'United States', 19.0, "Football Women's Football")
# ('Roy Allen Saari', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Summer Elisabeth Sanders (-Henderson, -Schlopy)', 'United States', 19.0, "Swimming Women's 200 metres Butterfly")
# ('Summer Elisabeth Sanders (-Henderson, -Schlopy)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Jennifer Lynn "Jenny" Schmidgall-Potter', 'United States', 19.0, "Ice Hockey Women's Ice Hockey")
# ('Charles Thomas "Charlie" Scott', 'United States', 19.0, "Basketball Men's Basketball")
# ('Ray P. Seales', 'United States', 19.0, "Boxing Men's Light-Welterweight")
# ('Kenneth Robert "Ken" Sitzberger', 'United States', 19.0, "Diving Men's Springboard")
# ('Ronald Ray "Ronnie Ray" Smith', 'United States', 19.0, "Athletics Men's 4 x 100 metres Relay")
# ('Michael Spinks', 'United States', 19.0, "Boxing Men's Middleweight")
# ('Richard Vaughn "Dick" Stebbins', 'United States', 19.0, "Athletics Men's 4 x 100 metres Relay")
# ('Margaret Ann "Maggie" Steffens', 'United States', 19.0, "Water Polo Women's Water Polo")
# ('Edward Glenister "Ed" Stevens, Jr.', 'United States', 19.0, "Rowing Men's Coxed Eights")
# ('Staciana Stitts (-Winfield)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Andrew Edward Strenk', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Frank Tate', 'United States', 19.0, "Boxing Men's Light-Middleweight")
# ('Hannah Lee Teter', 'United States', 19.0, "Snowboarding Women's Halfpipe")
# ('William Gluyas "Bill" Thompson', 'United States', 19.0, "Rowing Men's Coxed Eights")
# ('Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Virginia "Ginny" Thrasher', 'United States', 19.0, "Shooting Women's Air Rifle, 10 metres")
# ('Michael Francis "Mike" Troy', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Michael Francis "Mike" Troy', 'United States', 19.0, "Swimming Men's 200 metres Butterfly")
# ('Wyomia Tyus (-Simburg)', 'United States', 19.0, "Athletics Women's 100 metres")
# ('Matthew Haynes "Matt" Vogel', 'United States', 19.0, "Swimming Men's 100 metres Butterfly")
# ('Matthew Haynes "Matt" Vogel', 'United States', 19.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Mary Alice Wayte (-Bradburne)', 'United States', 19.0, "Swimming Women's 200 metres Freestyle")
# ('Mary Alice Wayte (-Bradburne)', 'United States', 19.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Peter Johann "Johnny" Weissmuller', 'United States', 19.0, "Swimming Men's 100 metres Freestyle")
# ('Peter Johann "Johnny" Weissmuller', 'United States', 19.0, "Swimming Men's 400 metres Freestyle")
# ('Peter Johann "Johnny" Weissmuller', 'United States', 19.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Abbey Weitzeil', 'United States', 19.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Rodney E. "Rod" White', 'United States', 19.0, "Archery Men's Team")
# ('Shaun Roger White', 'United States', 19.0, "Snowboarding Men's Halfpipe")
# ('Randel Lavelle "Randy" Williams', 'United States', 19.0, "Athletics Men's Long Jump")
# ('Thomas Mark "Tom" Williams', 'United States', 19.0, "Ice Hockey Men's Ice Hockey")
# ('Earl Verdelle Young', 'United States', 19.0, "Athletics Men's 4 x 400 metres Relay")
# ('Mariel Leigh Zagunis', 'United States', 19.0, "Fencing Women's Sabre, Individual")
# ('Charles "Chuck" Adkins', 'United States', 20.0, "Boxing Men's Light-Welterweight")
# ('Tenley Emma Albright (-Gardiner, -Blakely)', 'United States', 20.0, "Figure Skating Women's Singles")
# ('Debra Rae "Debbie" Armstrong', 'United States', 20.0, "Alpine Skiing Women's Giant Slalom")
# ('Michel Taylor "Tate" Armstrong', 'United States', 20.0, "Basketball Men's Basketball")
# ('Jane Louise Barkman (-Brown)', 'United States', 20.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Sybil Lorina Bauer', 'United States', 20.0, "Swimming Women's 100 metres Backstroke")
# ('Ralph Milton Beard, Jr.', 'United States', 20.0, "Basketball Men's Basketball")
# ('William Russell Becklean', 'United States', 20.0, "Rowing Men's Coxed Eights")
# ('Brooke Marie Bennett (-Frioud)', 'United States', 20.0, "Swimming Women's 400 metres Freestyle")
# ('Brooke Marie Bennett (-Frioud)', 'United States', 20.0, "Swimming Women's 800 metres Freestyle")
# ('Joseph "Gunnar" Bentz', 'United States', 20.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Richard "Ricky" Berens', 'United States', 20.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Isaac "Ike" Berger', 'United States', 20.0, "Weightlifting Men's Featherweight")
# ('Tell Schirnding Berna', 'United States', 20.0, "Athletics Men's 3,000 metres, Team")
# ('Ralph English Bishop', 'United States', 20.0, "Basketball Men's Basketball")
# ('Lee Everett Blair', 'United States', 20.0, 'Art Competitions Mixed Painting, Drawings And Water Colors')
# ('Richard Adolph "Dick" Blick', 'United States', 20.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Maddison Michelle "Maddie" Bowman', 'United States', 20.0, "Freestyle Skiing Women's Halfpipe")
# ('Ralph Theodore Breyer', 'United States', 20.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Neal LaMoy Broten', 'United States', 20.0, "Ice Hockey Men's Ice Hockey")
# ('David Preston "Dave" Brown', 'United States', 20.0, "Rowing Men's Coxed Eights")
# ('Thomas Edwin "Tom" Bruce', 'United States', 20.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Victoria Andrea "Vicky" Bullett', 'United States', 20.0, "Basketball Women's Basketball")
# ('Sean Patrick Burroughs', 'United States', 20.0, "Baseball Men's Baseball")
# ('Hubert Augustus Caldwell (-Aspinwall)', 'United States', 20.0, "Rowing Men's Coxed Eights")
# ('Kenneth Alan "Kenny" Carr', 'United States', 20.0, "Basketball Men's Basketball")
# ('Lauren Nicole Cheney (-Holiday)', 'United States', 20.0, "Football Women's Football")
# ('David William "Dave" Christian', 'United States', 20.0, "Ice Hockey Men's Ice Hockey")
# ('Sherman Rockwell "Sherm" Clark', 'United States', 20.0, "Rowing Men's Coxed Eights")
# ('Tammy P. Cleland-McGregor', 'United States', 20.0, "Synchronized Swimming Women's Team")
# ('Georgia V. Coleman (-Gilson)', 'United States', 20.0, "Diving Women's Springboard")
# ('Arthur Edwin "Art" Cook', 'United States', 20.0, "Shooting Men's Small-Bore Rifle, Prone, 50 metres")
# ('William Morris "Bill" Dally', 'United States', 20.0, "Rowing Men's Coxed Eights")
# ('William Thomas "Bill" Darnton', 'United States', 20.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Lindsay Ann Davenport', 'United States', 20.0, "Tennis Women's Singles")
# ('Howard Edward Davis, Jr.', 'United States', 20.0, "Boxing Men's Lightweight")
# ('Sara DeCosta (-Hayes)', 'United States', 20.0, "Ice Hockey Women's Ice Hockey")
# ('Diamond Brittany Dixon', 'United States', 20.0, "Athletics Women's 4 x 400 metres Relay")
# ('Thomas Fitzgerald "Tom" Dolan', 'United States', 20.0, "Swimming Men's 400 metres Individual Medley")
# ('Gabrielle Christina Victoria "Gabby" Douglas', 'United States', 20.0, "Gymnastics Women's Team All-Around")
# ('Annika Elise Madsen Dries', 'United States', 20.0, "Water Polo Women's Water Polo")
# ('Teresa Edwards', 'United States', 20.0, "Basketball Women's Basketball")
# ('Janet Beth Evans', 'United States', 20.0, "Swimming Women's 800 metres Freestyle")
# ('Aeriwentha Mae Faggs (-Starr)', 'United States', 20.0, "Athletics Women's 4 x 100 metres Relay")
# ('Maria Jose "Mary Joe" Fernandez (-Godsick)', 'United States', 20.0, "Tennis Women's Doubles")
# ('Hugh Miller Foley', 'United States', 20.0, "Rowing Men's Coxed Eights")
# ('Philip Jackson "Phil" Ford, Jr.', 'United States', 20.0, "Basketball Men's Basketball")
# ('Joseph "Joe" Frazier', 'United States', 20.0, "Boxing Men's Heavyweight")
# ('Vincent Joseph "Vince" Gallagher, Jr.', 'United States', 20.0, "Rowing Men's Coxed Eights")
# ('Robert "Bob" Garrett', 'United States', 20.0, "Athletics Men's Shot Put")
# ('Robert "Bob" Garrett', 'United States', 20.0, "Athletics Men's Discus Throw")
# ('Christopher Coleman "Chris" George', 'United States', 20.0, "Baseball Men's Baseball")
# ('Paul Garza Gonzales, Jr.', 'United States', 20.0, "Boxing Men's Light-Flyweight")
# ('Susanne "Sue" Gossick', 'United States', 20.0, "Diving Women's Springboard")
# ('Samuel Louis "Sam" Graddy, III', 'United States', 20.0, "Athletics Men's 4 x 100 metres Relay")
# ('Paul William Hait', 'United States', 20.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Darnell Kenneth Hall', 'United States', 20.0, "Athletics Men's 4 x 400 metres Relay")
# ('Winslow William Hall', 'United States', 20.0, "Rowing Men's Coxed Eights")
# ('Millard Frank Hampton, Jr.', 'United States', 20.0, "Athletics Men's 4 x 100 metres Relay")
# ('Thomas G. "Tommy" Hannan', 'United States', 20.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Ronald Woodson "Ronnie" Harris', 'United States', 20.0, "Boxing Men's Lightweight")
# ('Michael Steward "Mike" Heath', 'United States', 20.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('Michael Steward "Mike" Heath', 'United States', 20.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Michael Steward "Mike" Heath', 'United States', 20.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Tobin Powell Heath', 'United States', 20.0, "Football Women's Football")
# ('Harry Joseph Hebner', 'United States', 20.0, "Swimming Men's 100 metres Backstroke")
# ('Stephen Edward "Steve" Hegg', 'United States', 20.0, "Cycling Men's Individual Pursuit, 4,000 metres")
# ('Carol Elizabeth Heiss (-Jenkins)', 'United States', 20.0, "Figure Skating Women's Singles")
# ('Charles Monroe "Charlie" Hoag', 'United States', 20.0, "Basketball Men's Basketball")
# ('Dianne Mary Holum', 'United States', 20.0, "Speed Skating Women's 1,500 metres")
# ('Richard John "Dick" Howell', 'United States', 20.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('William Welles "Bill" Hoyt', 'United States', 20.0, "Athletics Men's Pole Vault")
# ('William DeHart Hubbard', 'United States', 20.0, "Athletics Men's Long Jump")
# ('George Elwood "Shorty" Hunt, Jr.', 'United States', 20.0, "Rowing Men's Coxed Eights")
# ('Joseph Garvin "Lou" Hunter', 'United States', 20.0, "Rugby Men's Rugby")
# ('Marcus Latimer Hurley', 'United States', 20.0, "Cycling Men's 1/4 mile")
# ('Marcus Latimer Hurley', 'United States', 20.0, "Cycling Men's 1/3 mile")
# ('Marcus Latimer Hurley', 'United States', 20.0, "Cycling Men's 1/2 mile")
# ('Marcus Latimer Hurley', 'United States', 20.0, "Cycling Men's 1 mile")
# ('Virgil Victor Jacomini', 'United States', 20.0, "Rowing Men's Coxed Eights")
# ('George Lawrence "Larry" James', 'United States', 20.0, "Athletics Men's 4 x 400 metres Relay")
# ('Donald Hendrik "Don" Johnston', 'United States', 20.0, "Rowing Men's Coxed Eights")
# ('Susanne Jean "Suzy" Jones (-Roy)', 'United States', 20.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Shaun M. Jordan', 'United States', 20.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('Daniel Ploug "Dan" Jorgensen', 'United States', 20.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Melvin Dean Kelley', 'United States', 20.0, "Basketball Men's Basketball")
# ('Frederick Warren "Fred" Kelly', 'United States', 20.0, "Athletics Men's 110 metres Hurdles")
# ('Robert Allan "Bob" Kiesel', 'United States', 20.0, "Athletics Men's 4 x 100 metres Relay")
# ('Leamon King', 'United States', 20.0, "Athletics Men's 4 x 100 metres Relay")
# ('John Pitann Kinsella', 'United States', 20.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Oliver Leonard Kirk', 'United States', 20.0, "Boxing Men's Bantamweight")
# ('Oliver Leonard Kirk', 'United States', 20.0, "Boxing Men's Featherweight")
# ('Sage Kotsenburg', 'United States', 20.0, "Snowboarding Men's Slopestyle")
# ('Adelaide T. Lambert (-Ballard)', 'United States', 20.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Alfred Page "Al" Lane', 'United States', 20.0, "Shooting Men's Free Pistol, 50 metres")
# ('Alfred Page "Al" Lane', 'United States', 20.0, "Shooting Men's Free Pistol, 50 metres, Team")
# ('Alfred Page "Al" Lane', 'United States', 20.0, "Shooting Men's Dueling Pistol, 30 metres")
# ('Brent Dennis Lang', 'United States', 20.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('Breeja Larson', 'United States', 20.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Lance Melvin Larson', 'United States', 20.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Lillie Mae Leatherwood (-King)', 'United States', 20.0, "Athletics Women's 4 x 400 metres Relay")
# ('Ray Charles "Sugar Ray" Leonard', 'United States', 20.0, "Boxing Men's Light-Welterweight")
# ('Alfred Damon "Al" Lindley', 'United States', 20.0, "Rowing Men's Coxed Eights")
# ('Ryan Steven Lochte', 'United States', 20.0, "Swimming Men's 4 x 200 metres Freestyle Relay")
# ('Eleanor "Elle" Logan', 'United States', 20.0, "Rowing Women's Coxed Eights")
# ('Jerry Ray Lucas', 'United States', 20.0, "Basketball Men's Basketball")
# ('Joseph Oliver MacDonald', 'United States', 20.0, "Athletics Men's 4 x 400 metres Relay")
# ('Madeline Manning-Jackson (-Mims)', 'United States', 20.0, "Athletics Women's 800 metres")
# ('Simone Ashley Manuel', 'United States', 20.0, "Swimming Women's 100 metres Freestyle")
# ('Simone Ashley Manuel', 'United States', 20.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Vincent Edward "Vince" Matthews', 'United States', 20.0, "Athletics Men's 4 x 400 metres Relay")
# ('Steven D. "Steve" McCrory', 'United States', 20.0, "Boxing Men's Flyweight")
# ('Richard Michael "Rich" McGeagh', 'United States', 20.0, "Swimming Men's 4 x 100 metres Medley Relay")
# ('Edith Marie McGuire (-Duvall)', 'United States', 20.0, "Athletics Women's 200 metres")
# ...
# ('Alice Ruth "Ruthie" Bolton-Holifield', 'United States', 33.0, "Basketball Women's Basketball")
# ('Horace Robert Bonser', 'United States', 33.0, "Shooting Men's Trap, Team")
# ('Kobe Bean Bryant', 'United States', 33.0, "Basketball Men's Basketball")
# ('Cornelius Lonzo Burdette', 'United States', 33.0, "Shooting Men's Military Rifle, 200, 400, 500 and 600 metres, Team")
# ('Daniel Brendon "Dan" Carroll', 'United States', 33.0, "Rugby Men's Rugby")
# ('Tamika Devonne Catchings', 'United States', 33.0, "Basketball Women's Basketball")
# ('Peter M. "Pete" Cipollone', 'United States', 33.0, "Rowing Men's Coxed Eights")
# ('Paul Vincent Costello', 'United States', 33.0, "Rowing Men's Double Sculls")
# ('George Louis Eyser', 'United States', 33.0, "Gymnastics Men's Horse Vault")
# ('George Louis Eyser', 'United States', 33.0, "Gymnastics Men's Parallel Bars")
# ('George Louis Eyser', 'United States', 33.0, "Gymnastics Men's Rope Climbing")
# ('Lisa M. Fernandez (-Lujan)', 'United States', 33.0, "Softball Women's Softball")
# ('Julie Maurine Foudy', 'United States', 33.0, "Football Women's Football")
# ('Harold H. "Hal" Haenel', 'United States', 33.0, 'Sailing Mixed Two Person Keelboat')
# ('Lori D. Harrigan (-Mack)', 'United States', 33.0, "Softball Women's Softball")
# ('Michael Duane Johnson', 'United States', 33.0, "Athletics Men's 400 metres")
# ('Richard Edward "Rich" Lambourne', 'United States', 33.0, "Volleyball Men's Volleyball")
# ('Kristine Marie Lilly (-Heavey)', 'United States', 33.0, "Football Women's Football")
# ('Patrick Joseph "Pat" McDonald (McDonnell-)', 'United States', 33.0, "Athletics Men's Shot Put")
# ('DeLisha Lachell Milton-Jones', 'United States', 33.0, "Basketball Women's Basketball")
# ('Meghan Musnicki', 'United States', 33.0, "Rowing Women's Coxed Eights")
# ('Hakeem Abdul Olajuwon', 'United States', 33.0, "Basketball Men's Basketball")
# ('Christie Patricia Pearce-Rampone', 'United States', 33.0, "Football Women's Football")
# ('Kimberly Susan "Kim" Rhode (-Harryman)', 'United States', 33.0, "Shooting Women's Skeet")
# ('James Edmund "Jim" Shea, Jr.', 'United States', 33.0, "Skeleton Men's Skeleton")
# ('Michele Mary Smith', 'United States', 33.0, "Softball Women's Softball")
# ('Karen Elizabeth Stives', 'United States', 33.0, 'Equestrianism Mixed Three-Day Event, Team')
# ('Sheryl Denice Swoopes', 'United States', 33.0, "Basketball Women's Basketball")
# ('Tina Marie Thompson', 'United States', 33.0, "Basketball Women's Basketball")
# ('Dara Grace Torres (-Hoffman, -Minas)', 'United States', 33.0, "Swimming Women's 4 x 100 metres Freestyle Relay")
# ('Dara Grace Torres (-Hoffman, -Minas)', 'United States', 33.0, "Swimming Women's 4 x 100 metres Medley Relay")
# ('Seth Benjamin Wescott', 'United States', 33.0, "Snowboarding Men's Boardercross")
# ('Charles Blish Winder, Jr.', 'United States', 33.0, "Shooting Men's Military Rifle, 200/500/600/800/900/1,000 Yards, Team")
# ('Kristin Ann Armstrong (-Savola)', 'United States', 34.0, "Cycling Women's Individual Time Trial")
# ('Huelet Leo "Joe" Benner', 'United States', 34.0, "Shooting Men's Free Pistol, 50 metres")
# ('Sheila Marie Cornell-Douty', 'United States', 34.0, "Softball Women's Softball")
# ('Bruce Oram Davidson', 'United States', 34.0, 'Equestrianism Mixed Three-Day Event, Team')
# ('Joseph Nicholas "Joe" DePietro', 'United States', 34.0, "Weightlifting Men's Bantamweight")
# ('Raymond Clarence "Ray" Ewry', 'United States', 34.0, "Athletics Men's Standing High Jump")
# ('Raymond Clarence "Ray" Ewry', 'United States', 34.0, "Athletics Men's Standing Long Jump")
# ('Conrad Francis "Conn" Findlay', 'United States', 34.0, "Rowing Men's Coxed Pairs")
# ('Yolanda Yvette Griffith', 'United States', 34.0, "Basketball Women's Basketball")
# ('Timothy Duane "Tim" Hardaway', 'United States', 34.0, "Basketball Men's Basketball")
# ('Edward Francis "Ed" Jennings', 'United States', 34.0, "Rowing Men's Coxed Pairs")
# ('John Brenden "Jack" Kelly, Sr.', 'United States', 34.0, "Rowing Men's Double Sculls")
# ('William Joseph "Bill" Knecht', 'United States', 34.0, "Rowing Men's Coxed Eights")
# ('Jearl Atawa Miles-Clark', 'United States', 34.0, "Athletics Women's 4 x 400 metres Relay")
# ('Heather Blaine Mitts (-Feeley)', 'United States', 34.0, "Football Women's Football")
# ('Heather Petri', 'United States', 34.0, "Water Polo Women's Water Polo")
# ('Dorothy Gay "Dot" Richardson', 'United States', 34.0, "Softball Women's Softball")
# ('Arthur Dale Rothrock', 'United States', 34.0, "Shooting Men's Small Bore-Rifle, Standing, 50 metres, Team")
# ('Charles Edward Sands', 'United States', 34.0, "Golf Men's Individual")
# ('Katherine May "Katie" Smith', 'United States', 34.0, "Basketball Women's Basketball")
# ('Melanie Ainsworth Smith (-Taylor)', 'United States', 34.0, 'Equestrianism Mixed Jumping, Team')
# ('Dawn Michelle Staley', 'United States', 34.0, "Basketball Women's Basketball")
# ('John Houston Stockton', 'United States', 34.0, "Basketball Men's Basketball")
# ('Diana Lurena Taurasi', 'United States', 34.0, "Basketball Women's Basketball")
# ('Torrance Watkins Fleischmann', 'United States', 34.0, 'Equestrianism Mixed Three-Day Event, Team')
# ('Lindsay Marie Whalen', 'United States', 34.0, "Basketball Women's Basketball")
# ('Evelyn Ashford (-Washington)', 'United States', 35.0, "Athletics Women's 4 x 100 metres Relay")
# ('Larry Joe Bird', 'United States', 35.0, "Basketball Men's Basketball")
# ('Suzanne Brigit "Sue" Bird', 'United States', 35.0, "Basketball Women's Basketball")
# ('Shannon Leigh Boxx', 'United States', 35.0, "Football Women's Football")
# ('Anthony Lee Ervin', 'United States', 35.0, "Swimming Men's 50 metres Freestyle")
# ('Anthony Lee Ervin', 'United States', 35.0, "Swimming Men's 4 x 100 metres Freestyle Relay")
# ('Joseph Webster Golinkin', 'United States', 35.0, 'Art Competitions Mixed Painting, Graphic Arts')
# ('Thomas John "Tom" Hoff', 'United States', 35.0, "Volleyball Men's Volleyball")
# ('Jason Frederick Kidd', 'United States', 35.0, "Basketball Men's Basketball")
# ('Frederick Carlton "Carl" Lewis', 'United States', 35.0, "Athletics Men's Long Jump")
# ('Stephen John "Steve" Lysak', 'United States', 35.0, "Canoeing Men's Canadian Doubles, 10,000 metres")
# ('Kenneth "Ken" Myers', 'United States', 35.0, "Rowing Men's Double Sculls")
# ('Carl Townsend Osburn', 'United States', 35.0, "Shooting Men's Free Rifle, Three Positions, 300 metres, Team")
# ('Carl Townsend Osburn', 'United States', 35.0, "Shooting Men's Military Rifle, Prone, 300 metres, Team")
# ('Carl Townsend Osburn', 'United States', 35.0, "Shooting Men's Military Rifle, Standing, 300 metres")
# ('Carl Townsend Osburn', 'United States', 35.0, "Shooting Men's Military Rifle, 300 metres and 600 metres, Prone, Team")
# ('Lloyd Spencer Spooner', 'United States', 35.0, "Shooting Men's Free Rifle, Three Positions, 300 metres, Team")
# ('Lloyd Spencer Spooner', 'United States', 35.0, "Shooting Men's Military Rifle, Prone, 300 metres, Team")
# ('Lloyd Spencer Spooner', 'United States', 35.0, "Shooting Men's Military Rifle, Prone, 600 metres, Team")
# ('Lloyd Spencer Spooner', 'United States', 35.0, "Shooting Men's Military Rifle, 300 metres and 600 metres, Prone, Team")
# ('Lones Wesley Wigger, Jr.', 'United States', 35.0, 'Shooting Mixed Free Rifle, Three Positions, 300 metres')
# ('Edwin Yancey "Eddie" Argo', 'United States', 36.0, "Equestrianism Men's Three-Day Event, Team")
# ('Lloy James Ball', 'United States', 36.0, "Volleyball Men's Volleyball")
# ('John Keith Boles', 'United States', 36.0, "Shooting Men's Running Target, Single Shot")
# ('Brandi Denise Chastain', 'United States', 36.0, "Football Women's Football")
# ('Teresa Edwards', 'United States', 36.0, "Basketball Women's Basketball")
# ('Joseph Halpin "Joe" Fargis, IV', 'United States', 36.0, 'Equestrianism Mixed Jumping, Individual')
# ('Joseph Halpin "Joe" Fargis, IV', 'United States', 36.0, 'Equestrianism Mixed Jumping, Team')
# ('Joy Lynn Fawcett (Biefeld-)', 'United States', 36.0, "Football Women's Football")
# ('John Joseph Flanagan', 'United States', 36.0, "Athletics Men's Hammer Throw")
# ('Lisa Deshawn Leslie (-Lockwood)', 'United States', 36.0, "Basketball Women's Basketball")
# ('Matthew John "Matt" McGrath', 'United States', 36.0, "Athletics Men's Hammer Throw")
# ('John Hopkins Noel', 'United States', 36.0, "Shooting Men's Trap, Team")
# ('John Michael Plumb', 'United States', 36.0, 'Equestrianism Mixed Three-Day Event, Team')
# ('Mark Jeffrey Reynolds', 'United States', 36.0, 'Sailing Mixed Two Person Keelboat')
# ('Ralph Lewis Spotts', 'United States', 36.0, "Shooting Men's Trap, Team")
# ('Patrick Lance "Pat" Borders', 'United States', 37.0, "Baseball Men's Baseball")
# ('Tamika Devonne Catchings', 'United States', 37.0, "Basketball Women's Basketball")
# ('John A. Dietz', 'United States', 37.0, "Shooting Men's Free Pistol, 50 yards, Team")
# ('William Evans Garrett Gilmore', 'United States', 37.0, "Rowing Men's Double Sculls")
# ('Chris Kappler', 'United States', 37.0, 'Equestrianism Mixed Jumping, Team')
# ('Christie Patricia Pearce-Rampone', 'United States', 37.0, "Football Women's Football")
# ('Albertson Van Zo Post', 'United States', 37.0, "Fencing Men's Foil, Team")
# ('Albertson Van Zo Post', 'United States', 37.0, "Fencing Men's Single Sticks, Individual")
# ('Marcus Mills Pomeroy "Mark" Arie', 'United States', 38.0, "Shooting Men's Trap")
# ('Marcus Mills Pomeroy "Mark" Arie', 'United States', 38.0, "Shooting Men's Trap, Team")
# ('Kristin Ann Armstrong (-Savola)', 'United States', 38.0, "Cycling Women's Individual Time Trial")
# ('Sheila Marie Cornell-Douty', 'United States', 38.0, "Softball Women's Softball")
# ('Frank Sherman Henry', 'United States', 38.0, "Equestrianism Men's Three-Day Event, Team")
# ('Lowell Orton North', 'United States', 38.0, 'Sailing Mixed Two Person Keelboat')
# ("David O'Connor", 'United States', 38.0, 'Equestrianism Mixed Three-Day Event, Individual')
# ('Dorothy Gay "Dot" Richardson', 'United States', 38.0, "Softball Women's Softball")
# ('Warren Austin Sprout', 'United States', 38.0, "Shooting Men's Military Rifle, 200, 400, 500 and 600 metres, Team")
# ('Frank Merlin Troeh', 'United States', 38.0, "Shooting Men's Trap, Team")
# ('Allan Lindsay Briggs', 'United States', 39.0, "Shooting Men's Military Rifle, 200, 400, 500 and 600 metres, Team")
# ('Fred Rudolph Etchen, Sr.', 'United States', 39.0, "Shooting Men's Trap, Team")
# ('Karl Telford Frederick', 'United States', 39.0, "Shooting Men's Military Pistol, Team")
# ('Karl Telford Frederick', 'United States', 39.0, "Shooting Men's Free Pistol, 50 metres")
# ('Karl Telford Frederick', 'United States', 39.0, "Shooting Men's Free Pistol, 50 metres, Team")
# ('John Henry Hendrickson', 'United States', 39.0, "Shooting Men's Trap, Team")
# ('Joseph "Joe" Jackson', 'United States', 39.0, "Shooting Men's Military Rifle, Prone, 300 metres, Team")
# ('Joseph "Joe" Jackson', 'United States', 39.0, "Shooting Men's Military Rifle, Prone, 600 metres, Team")
# ('Joseph "Joe" Jackson', 'United States', 39.0, "Shooting Men's Military Rifle, 300 metres and 600 metres, Prone, Team")
# ('Patrick James "Paddy" Ryan', 'United States', 39.0, "Athletics Men's Hammer Throw")
# ('William Sylvester "Bill" Silkworth', 'United States', 39.0, "Shooting Men's Trap, Team")
# ('Peter Wylde', 'United States', 39.0, 'Equestrianism Mixed Jumping, Team')
# ('Charles Sumner Benedict', 'United States', 40.0, "Shooting Men's Military Rifle, 200/500/600/800/900/1,000 Yards, Team")
# ('Jay Clark, Jr.', 'United States', 40.0, "Shooting Men's Trap, Team")
# ('John Joseph Flanagan', 'United States', 40.0, "Athletics Men's Hammer Throw")
# ('Paul Jeffrey Foerster', 'United States', 40.0, "Sailing Men's Two Person Dinghy")
# ('Richard Andrew "Butch" Johnson', 'United States', 40.0, "Archery Men's Team")
# ('Elizabeth "Beezie" Madden (Patton-)', 'United States', 40.0, 'Equestrianism Mixed Jumping, Team')
# ('Ollie Martin Schriver', 'United States', 40.0, "Shooting Men's Military Rifle, Prone, 600 metres, Team")
# ('Ollie Martin Schriver', 'United States', 40.0, "Shooting Men's Military Rifle, 300 metres and 600 metres, Prone, Team")
# ('Ollie Martin Schriver', 'United States', 40.0, "Shooting Men's Small Bore-Rifle, Standing, 50 metres, Team")
# ('James Howard Snook', 'United States', 40.0, "Shooting Men's Military Pistol, Team")
# ('James Howard Snook', 'United States', 40.0, "Shooting Men's Free Pistol, 50 metres, Team")
# ('John A. Dietz', 'United States', 41.0, "Shooting Men's Free Pistol, 50 metres, Team")
# ('William Brittain Martin', 'United States', 41.0, "Shooting Men's Military Rifle, 200/500/600/800/900/1,000 Yards, Team")
# ('Patrick Joseph "Pat" McDonald (McDonnell-)', 'United States', 41.0, "Athletics Men's 56-pound Weight Throw")
# ('Harry Edward Sears', 'United States', 41.0, "Shooting Men's Free Pistol, 50 metres, Team")
# ('Frank Seymour Wright', 'United States', 41.0, "Shooting Men's Trap, Team")
# ('Kristin Ann Armstrong (-Savola)', 'United States', 42.0, "Cycling Women's Individual Time Trial")
# ('William Bruce "Bill" Bentsen', 'United States', 42.0, 'Sailing Mixed Three Person Keelboat')
# ('Edward Francis Gleason', 'United States', 42.0, "Shooting Men's Trap, Team")
# ('James Robert "Jay" Graham', 'United States', 42.0, "Shooting Men's Trap")
# ('James Robert "Jay" Graham', 'United States', 42.0, "Shooting Men's Trap, Team")
# ('Laura Kraut (Kent-)', 'United States', 42.0, 'Equestrianism Mixed Jumping, Team')
# ('Harry Clemens "Buddy" Melges, Jr.', 'United States', 42.0, 'Sailing Mixed Three Person Keelboat')
# ('Doreen Viola Wilber (Hansen-)', 'United States', 42.0, "Archery Women's Individual")
# ('Frank Henry Hughes', 'United States', 43.0, "Shooting Men's Trap, Team")
# ('William Clark "Bill" Steinkraus', 'United States', 43.0, 'Equestrianism Mixed Jumping, Individual')
# ('Matilda "Lida" Howell (Scott-)', 'United States', 44.0, "Archery Women's Double Columbia Round")
# ('Matilda "Lida" Howell (Scott-)', 'United States', 44.0, "Archery Women's Double National Round")
# ('William David Franz "Bill" Leushner', 'United States', 44.0, "Shooting Men's Military Rifle, 200/500/600/800/900/1,000 Yards, Team")
# ('Elizabeth "Beezie" Madden (Patton-)', 'United States', 44.0, 'Equestrianism Mixed Jumping, Team')
# ('Forest Waldemar McNeir', 'United States', 44.0, "Shooting Men's Trap, Team")
# ('John Michael Plumb', 'United States', 44.0, 'Equestrianism Mixed Three-Day Event, Team')
# ('Mark Jeffrey Reynolds', 'United States', 44.0, 'Sailing Mixed Two Person Keelboat')
# ('Samuel Henry "Sam" Sharman', 'United States', 44.0, "Shooting Men's Trap, Team")
# ('Charles W. Billings', 'United States', 45.0, "Shooting Men's Trap, Team")
# ('Harry Dwight Chamberlin', 'United States', 45.0, "Equestrianism Men's Three-Day Event, Team")
# ('Frank Hall', 'United States', 46.0, "Shooting Men's Trap, Team")
# ('Magnus Liljedahl', 'United States', 46.0, 'Sailing Mixed Two Person Keelboat')
# ('Rbert Zimonyi', 'United States', 46.0, "Rowing Men's Coxed Eights")
# ('Kevin Lobdell Burnham', 'United States', 47.0, "Sailing Men's Two Person Dinghy")
# ('Earl Foster Thomson', 'United States', 47.0, "Equestrianism Men's Three-Day Event, Team")
# ('Michael "Mike" Kelly', 'United States', 48.0, "Shooting Men's Military Pistol, Team")
# ('Michael "Mike" Kelly', 'United States', 48.0, "Shooting Men's Free Pistol, 50 metres, Team")
# ('Charles Sumner Axtell', 'United States', 49.0, "Shooting Men's Free Pistol, 50 yards, Team")
# ('William Earl Buchan, Sr.', 'United States', 49.0, 'Sailing Mixed Two Person Keelboat')
# ('James Edward "Jim" Gorman', 'United States', 49.0, "Shooting Men's Free Pistol, 50 yards, Team")
# ('William "Will" Simpson', 'United States', 49.0, 'Equestrianism Mixed Jumping, Team')
# ('Clarence Bitters Platt', 'United States', 50.0, "Shooting Men's Trap, Team")
# ('Mahonri Mackintosh Young', 'United States', 54.0, 'Art Competitions Mixed Sculpturing, Statues')
# ('Walter Winans', 'United States', 56.0, "Shooting Men's Running Target, Double Shot")
# ('Walter Winans', 'United States', 60.0, 'Art Competitions Mixed Sculpturing')
# ('Charles Jacobus', 'United States', 64.0, "Roque Men's Singles")
